# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

xi = [0.2, 0.3, 0.6, 0.9, 1.1, 1.3, 1.4, 1.6]
yi = [0.050446, 0.098426, 0.33277, 0.72660, 1.0972, 1.5697, 1.8487, 2.501]
# Definición de la función
def func_pow(x, b, a):
    return b * x ** a

# Ajuste
params_pow, _ = curve_fit(func_pow, xi, yi)

# Error cuadrático medio
error_pow = np.mean((func_pow(xi, *params_pow) - yi) ** 2)

# Gráfica
plt.scatter(xi, yi, label='Datos')
plt.plot(xi, func_pow(xi, *params_pow), label='Ajuste potencia', color='orange')
plt.legend()
plt.xlabel('xi')
plt.ylabel('yi')
plt.title('Ajuste potencia')
plt.show()

print(f"Parámetros de la forma y=bx^a: {params_pow}")
print(f"Error de la forma y=bx^a: {error_pow}")
# Out:
# Parámetros de la forma y=bx^a: [0.90558024 2.14232168]
# Error de la forma y=bx^a: 0.00043314119304844534
